# %%
a=input("enter a number:")
b=input("enter second number:")
print ("the sum",a,"+",b,"is:",int(a)+ int(b))
print ("the sum",a,"-",b,"is:",int(a)- int(b))
print ("the sum",a,"*",b,"is:",int(a)* int(b))
print ("the sum",a,"/",b,"is:",int(a)/ int(b))
# Out:
# enter a number:12
# enter second number:12
# the sum 12 + 12 is: 24
# the sum 12 - 12 is: 0
# the sum 12 * 12 is: 144
# the sum 12 / 12 is: 1.0

# %%
list1=[4,2,7,4,9,6,1,8,3]
list1.sort()
print(list1)
print(list1[0])
# Out:
# [1, 2, 3, 4, 4, 6, 7, 8, 9]
# 1

# %%
store="dong"
a=input("enter the productyou waant")
b=input("enter the quentity")
c=input("wnter the price")
d=input("enter the discount")
print()

# %%
thisstore={
    "noodle":"Wai Wai",
    "brand":"CG",
    "price":100,
    "discout":50,


}
for x in thisstore:
  print(thisstore[x])
# Out:
# Wai Wai
# CG
# 100
# 50

# %%
#Example of iteration
class  MyIterator:
  def __init__(self,data):
    self.data=data
    self.index=0
  def __iter__(self):
    return self
  def __next__(self):
    if self.index>=len(self.data):
      raise StopIteration
    print(f"Getting index:{self.index}")
    value=self.data[self.index]
    self.index+=1
    return value
my_list=[1,2,3,4,5]
my_iter=MyIterator(my_list)
for num in my_iter:
  print(num)

# %%
#polimorphism
class Animal:
  def speak(self):
    pass
class Dog(Animal):
  def speak(self):
    return "woolf"
class Cat(Animal):
  def speak(self):
    return"meow"
dog=Dog()
cat=Cat()
for animal in (dog,cat):
  print(animal.speak())

# %%
#abstractmethoid
from abc import ABC,abstractmethod
class Vehicle(ABC):
  @abstractmethod
  def drive(self):
    print("Vehicle is driving")
  def new_fn(self):
    print("My new fn")
class Car(Vehicle):
  pass
car=Car()
print(car.drive()) #it should be error beacause it's a part of abstractmethod

# %%
#encapsulation
class BankAccount:
  def __init__(self,name):
    self._balance=0
    self.name=name
  def deposit(self,amount):
    self._balance +=amount
  def withdraw(self,amount):
    self._balance -=amount
  def get_balance(self):
    return self._balance
  def __str__(self):
    return f"name:{self.name}and Balance:Hidden"
ruman=BankAccount("Ruman")
ruman.deposit(1000)
print(ruman)
print(ruman.get_balance())
ruman.withdraw(500)
ruman.deposit(3000)
ruman.withdraw(1000)
print(ruman.get_balance())
